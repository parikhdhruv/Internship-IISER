# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('C:\\Users\HP\IIserIntern.csv')

# %%
train.head()
# Out:
#                         Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0  1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1  1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2  1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3  1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4  1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
#
#    Root Mean Square  Type_Earthquake  Type_Explosion  Type_Nuclear Explosion  \
# 0          1.022784                1               0                       0
# 1          1.022784                1               0                       0
# 2          1.022784                1               0                       0
# 3          1.022784                1               0                       0
# 4          1.022784                1               0                       0
#
# ...

# %%
train= train[train['Type_Earthquake']  > 0]

# %%
train.head()
# Out:
#                         Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0  1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1  1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2  1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3  1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4  1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
#
#    Root Mean Square  Type_Earthquake  Type_Explosion  Type_Nuclear Explosion  \
# 0          1.022784                1               0                       0
# 1          1.022784                1               0                       0
# 2          1.022784                1               0                       0
# 3          1.022784                1               0                       0
# 4          1.022784                1               0                       0
#
# ...

# %%
train.year.value_counts()
# Out:
# 2011    713
# 2007    608
# 1995    589
# 2004    571
# 2010    559
# 2000    553
# 1996    540
# 2005    533
# 1992    532
# 1990    524
# 2009    517
# 2006    508
# 2008    508
# 1994    506
# 1987    489
# 2003    485
# 1986    484
# 2014    480
# 1988    479
# 1989    473
# 1985    469
# 2016    469
# 1984    467
# 1993    465
# 2013    461
# 1997    456
# 1976    447
# 1999    446
# 2015    446
# 2012    445
# 2002    444
# 1983    443
# 2001    443
# 1991    428
# 1977    417
# 1975    402
# 1978    395
# 1973    394
# 1998    388
# 1972    388
# 1971    386
# 1974    355
# 1970    344
# 1979    343
# 1982    340
# 1965    339
# 1980    335
# 1969    322
# 1981    313
# 1968    303
# 1967    255
# 1966    233
# Name: year, dtype: int64

# %%
import matplotlib.pyplot as plt

train.year.value_counts().sort_values().plot(kind='bar', figsize=(24, 6), rot=0)
# Out:
# <AxesSubplot:>

# %%
train.Month.value_counts()
# Out:
# Mar    2104
# Aug    2000
# Dec    1977
# Sep    1972
# Nov    1970
# Apr    1959
# May    1945
# Oct    1924
# Jan    1888
# Jul    1865
# Feb    1821
# Jun    1807
# Name: Month, dtype: int64

# %%
train.Month.value_counts().sort_values().plot(kind='bar', figsize=(24, 6), rot=0)
# Out:
# <AxesSubplot:>

# %%
train = train.dropna(subset=[ 'address'], how='all')

# %%
train.head()
# Out:
#                          Date      Time  Latitude  Longitude  Depth  \
# 1   1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0
# 5   1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0
# 6   1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0
# 10  1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9
# 11  1965-01-24 00:00:00+00:00  00:11:17    -2.608    125.952   20.0
#
#     Magnitude  Root Mean Square  Type_Earthquake  Type_Explosion  \
# 1         5.8          1.022784                1               0
# 5         6.7          1.022784                1               0
# 6         5.9          1.022784                1               0
# 10        5.9          1.022784                1               0
# 11        8.2          1.022784                1               0
#
#     Type_Nuclear Explosion  ...  Magnitude Type_MWB  Magnitude Type_MWC  \
# 1                        0  ...                   0                   0
# ...

# %%
train['address'].isnull().sum()
# Out:
# 0

# %%
train.head(12)
# Out:
#                          Date      Time  Latitude  Longitude  Depth  \
# 1   1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0
# 5   1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0
# 6   1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0
# 10  1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9
# 11  1965-01-24 00:00:00+00:00  00:11:17    -2.608    125.952   20.0
# 12  1965-01-29 00:00:00+00:00  09:35:30    54.636    161.703   55.0
# 14  1965-02-02 00:00:00+00:00  15:56:51    37.523     73.251   15.0
# 23  1965-02-04 00:00:00+00:00  07:43:43    52.611    172.588   24.0
# 26  1965-02-04 00:00:00+00:00  08:40:44    51.443    179.605   30.0
# 48  1965-02-07 00:00:00+00:00  09:25:52    51.294    179.092   25.0
# 49  1965-02-08 00:00:00+00:00  15:46:52    55.223    165.426   32.5
# 50  1965-02-09 00:00:00+00:00  05:42:05   -18.718    169.386  200.0
#
#     Magnitude  Root Mean Square  Type_Earthquake  Type_Explosion  \
# ...

# %%
train['Country1'] = train['address'].str.split(',').apply(lambda x: x[-1])

# %%
train['Country1']
# Out:
# 1             Indonesia
# 5               Vanuatu
# 6                 नेपाल
# 10            Indonesia
# 11            Indonesia
#               ...
# 23406     United States
# 23407     United States
# 23408     United States
# 23409                日本
# 23410         Indonesia
# Name: Country1, Length: 10972, dtype: object

# %%
#train = train[train['Country1'] == 'India']

# %%
train.head()
# Out:
#                          Date      Time  Latitude  Longitude  Depth  \
# 1   1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0
# 5   1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0
# 6   1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0
# 10  1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9
# 11  1965-01-24 00:00:00+00:00  00:11:17    -2.608    125.952   20.0
#
#     Magnitude  Root Mean Square  Type_Earthquake  Type_Explosion  \
# 1         5.8          1.022784                1               0
# 5         6.7          1.022784                1               0
# 6         5.9          1.022784                1               0
# 10        5.9          1.022784                1               0
# 11        8.2          1.022784                1               0
#
#     Type_Nuclear Explosion  ...  Magnitude Type_MWC  Magnitude Type_MWR  \
# 1                        0  ...                   0                   0
# ...

# %%
train.drop(['month','geom','geometry','address','Type_Nuclear Explosion','Type_Explosion','Type_Rock Burst'],axis=1,inplace=True)

# %%
train.head(12)
# Out:
#                          Date      Time  Latitude  Longitude  Depth  \
# 1   1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0
# 5   1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0
# 6   1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0
# 10  1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9
# 11  1965-01-24 00:00:00+00:00  00:11:17    -2.608    125.952   20.0
# 12  1965-01-29 00:00:00+00:00  09:35:30    54.636    161.703   55.0
# 14  1965-02-02 00:00:00+00:00  15:56:51    37.523     73.251   15.0
# 23  1965-02-04 00:00:00+00:00  07:43:43    52.611    172.588   24.0
# 26  1965-02-04 00:00:00+00:00  08:40:44    51.443    179.605   30.0
# 48  1965-02-07 00:00:00+00:00  09:25:52    51.294    179.092   25.0
# 49  1965-02-08 00:00:00+00:00  15:46:52    55.223    165.426   32.5
# 50  1965-02-09 00:00:00+00:00  05:42:05   -18.718    169.386  200.0
#
#     Magnitude  Root Mean Square  Type_Earthquake  Status_Automatic  \
# ...

# %%
train['Country1'].value_counts()
# Out:
#  Indonesia               2484
#  Papua Niugini           1183
#  Vanuatu                  568
#  United States            510
#  Solomon Islands          432
#                          ...
# Saint Kitts and Nevis       1
# Shqipëria                   1
#  Paraguay / Paraguái        1
# Kenya                       1
# Ísland                      1
# Name: Country1, Length: 152, dtype: int64

# %%
train.sort_values(by="Country1",inplace=True)

# %%
test=train.iloc[1204:3688]

# %%
test.head()
# Out:
#                             Date      Time  Latitude  Longitude  Depth  \
# 11577  1993-09-01 00:00:00+00:00  14:03:19     2.986     96.122   34.0
# 11039  1992-08-02 00:00:00+00:00  05:50:12    -0.883    127.582   18.9
# 11040  1992-08-02 00:00:00+00:00  12:03:20    -7.126    121.748  485.9
# 11747  1994-01-07 00:00:00+00:00  19:23:53    -0.591     98.601   29.7
# 11630  1993-09-29 00:00:00+00:00  11:16:04     0.494    121.528   96.6
#
#        Magnitude  Root Mean Square  Type_Earthquake  Status_Automatic  \
# 11577        6.3               1.2                1                 0
# 11039        6.3               1.1                1                 0
# 11040        6.6               1.0                1                 0
# 11747        5.6               1.0                1                 0
# 11630        6.4               1.2                1                 0
#
#        Status_Reviewed  ...  Magnitude Type_ML  Magnitude Type_MS  \
# ...

# %%
test1= test[test['Month']=='Mar']

# %%
test1.head(444)
# Out:
#                             Date      Time  Latitude  Longitude  Depth  \
# 12358  1995-03-20 00:00:00+00:00  08:14:52    -8.012    116.494  231.8
# 12357  1995-03-19 00:00:00+00:00  23:53:15    -4.183    135.109   33.0
# 12356  1995-03-19 00:00:00+00:00  18:34:04    -4.231    135.013   19.2
# 12350  1995-03-14 00:00:00+00:00  10:27:31     3.050     95.845   30.1
# 12349  1995-03-13 00:00:00+00:00  10:31:46    -2.788    134.377    8.2
# ...                          ...       ...       ...        ...    ...
# 6138   1982-03-19 00:00:00+00:00  00:17:52    -2.802    138.811   48.0
# 94     1965-03-21 00:00:00+00:00  11:08:19    -1.547    126.623   28.9
# 6129   1982-03-06 00:00:00+00:00  11:35:07    -0.774    136.255   46.0
# 93     1965-03-19 00:00:00+00:00  16:20:53    -1.887    119.836   40.0
# 6144   1982-03-26 00:00:00+00:00  04:56:32    -6.845    129.399  181.0
#
#        Magnitude  Root Mean Square  Type_Earthquake  Status_Automatic  \
# ...

# %%
test1.sort_values(by='Date',inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20316\4028892423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1.sort_values(by='Date',inplace=True)

# %%
test1.head(232)
# Out:
#                             Date      Time  Latitude  Longitude   Depth  \
# 93     1965-03-19 00:00:00+00:00  16:20:53   -1.8870   119.8360   40.00
# 94     1965-03-21 00:00:00+00:00  11:08:19   -1.5470   126.6230   28.90
# 385    1966-03-08 00:00:00+00:00  06:00:07    1.7420   126.3370   35.00
# 384    1966-03-08 00:00:00+00:00  05:41:06    1.9030   126.3340   35.00
# 640    1967-03-19 00:00:00+00:00  01:10:51   -6.7270   129.7440   97.70
# ...                          ...       ...       ...        ...     ...
# 22569  2015-03-17 00:00:00+00:00  22:12:29    1.6686   126.5217   44.00
# 22578  2015-03-28 00:00:00+00:00  22:28:51    0.4002   121.9895  118.00
# 22579  2015-03-29 00:00:00+00:00  07:50:54    1.6535   126.4846   45.05
# 23023  2016-03-19 00:00:00+00:00  08:51:25   -5.5662   129.4922  269.80
# 23033  2016-03-29 00:00:00+00:00  09:18:11    2.3874   126.1019   55.00
#
#        Magnitude  Root Mean Square  Type_Earthquake  Status_Automatic  \
# ...

# %%
test1.drop(['Date','Time','Type_Earthquake','Country1','Month'],axis=1,inplace=True)

# %%
train_new= test1[test1['year']<=2000]

# %%
train_new.head(232)
# Out:
#        Latitude  Longitude  Depth  Magnitude  Root Mean Square  \
# 93       -1.887    119.836   40.0        6.0          1.022784
# 94       -1.547    126.623   28.9        6.3          1.022784
# 385       1.742    126.337   35.0        5.6          1.022784
# 384       1.903    126.334   35.0        6.2          1.022784
# 640      -6.727    129.744   97.7        6.2          1.022784
# ...         ...        ...    ...        ...               ...
# 14317    -7.028    117.089  621.4        5.5          0.800000
# 14320    -3.857    131.430   25.0        5.6          1.150000
# 14753    -7.321    128.491  141.9        6.4          0.910000
# 14761     4.738     96.007   33.0        5.5          1.330000
# 14773     3.155    128.034  102.7        5.9          0.980000
#
#        Status_Automatic  Status_Reviewed  Magnitude Type_MB  \
# 93                    1                0                  0
# 94                    1                0                  0
# ...

# %%
test_new= test1[test1['year']>=2000]

# %%
test_new.head(222)
# Out:
#        Latitude  Longitude   Depth  Magnitude  Root Mean Square  \
# 14753   -7.3210   128.4910  141.90        6.4              0.91
# 14761    4.7380    96.0070   33.00        5.5              1.33
# 14773    3.1550   128.0340  102.70        5.9              0.98
# 15331   -7.2060   106.1160   33.00        5.8              0.91
# 15333    0.4510   121.8920  109.40        6.0              0.83
# ...         ...        ...     ...        ...               ...
# 22569    1.6686   126.5217   44.00        6.2              0.85
# 22578    0.4002   121.9895  118.00        5.9              0.88
# 22579    1.6535   126.4846   45.05        5.6              0.94
# 23023   -5.5662   129.4922  269.80        5.7              0.76
# 23033    2.3874   126.1019   55.00        5.5              1.27
#
#        Status_Automatic  Status_Reviewed  Magnitude Type_MB  \
# 14753                 0                1                  0
# 14761                 0                1                  0
# ...

# %%
train_new.drop(['year'],axis=1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20316\624508550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new.drop(['year'],axis=1,inplace=True)

# %%
test_new.drop(['year'],axis=1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20316\3810021009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_new.drop(['year'],axis=1,inplace=True)

# %%
y_train=train_new.loc[:,'Magnitude']

# %%
y_train
# Out:
# 93       6.0
# 94       6.3
# 385      5.6
# 384      6.2
# 640      6.2
#         ...
# 14317    5.5
# 14320    5.6
# 14753    6.4
# 14761    5.5
# 14773    5.9
# Name: Magnitude, Length: 126, dtype: float64

# %%
x=train_new
x.drop(['Magnitude'],axis=1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20316\45599324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.drop(['Magnitude'],axis=1,inplace=True)

# %%
y_test=test_new.loc[:,'Magnitude']

# %%
x_test=test_new
x_test.drop(['Magnitude'],axis=1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20316\3348160343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test.drop(['Magnitude'],axis=1,inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
 regr = RandomForestRegressor(max_depth=2, random_state=0)

# %%
regr.fit(x, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
pred=regr.predict(x_test)

# %%
print(pred)
# Out:
# [[6.339134 ]
#  [4.315379 ]
#  [6.1835356]
#  [4.970136 ]
#  [5.9708986]
#  [5.790186 ]
#  [5.779127 ]
#  [6.366652 ]
#  [5.872069 ]
#  [5.848723 ]
#  [5.741288 ]
#  [6.3671064]
#  [5.714411 ]
#  [6.235119 ]
#  [6.261597 ]
#  [5.926489 ]
#  [6.0756226]
#  [6.1531773]
#  [6.092374 ]
#  [6.10695  ]
#  [5.7123594]
#  [5.601361 ]
#  [5.756071 ]
#  [5.912801 ]
#  [5.7416215]
#  [5.7134743]
#  [6.009739 ]
#  [6.180225 ]
#  [5.7208357]
#  [4.7572527]
#  [5.7069807]
#  [5.5830846]
#  [4.39232  ]
#  [4.4184437]
#  [4.40727  ]
#  [4.370776 ]
#  [4.4183025]
#  [4.392334 ]
#  [4.397188 ]
#  [4.496659 ]
#  [4.3817725]
#  [4.4404697]
#  [4.4481573]
#  [4.4938736]
#  [4.57934  ]
#  [5.8048654]
#  [3.8565092]
#  [5.264099 ]
#  [5.7380276]
#  [5.6595383]
#  [4.786656 ]
#  [4.7312026]
#  [4.3923492]
#  [6.367684 ]
#  [5.731799 ]
#  [5.16471  ]
#  [5.7272973]
#  [5.3375044]
#  [5.7401395]
#  [4.5763073]
#  [4.614833 ]
#  [6.181209 ]
#  [4.530912 ]
#  [5.327573 ]
#  [6.8196497]
#  [6.1965475]
# ...

# %%
import math
MSE = np.square(np.subtract(pred,y_test)).mean()
RMSE=math.sqrt(MSE)
print(RMSE)
# Out:
# 0.46071941265082506

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = keras.Sequential([
    keras.layers.Dense(16, input_shape=(16,), activation='relu'),
    keras.layers.Dense(20,activation='relu'),
     keras.layers.Dense(16,activation='relu'),
     keras.layers.Dense(12,activation='relu'),
    keras.layers.Dense(1, activation='linear') 
])

model.compile(optimizer='adam',
              loss='mse',
            )

model.fit(x, y_train, epochs=1000)
pred1=model.predict(x_test)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 77.1287
# Epoch 2/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 31.1716
# Epoch 3/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 10.2965
# Epoch 4/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 5.7391
# Epoch 5/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 5.1512
# Epoch 6/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 4.0440
# Epoch 7/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0038
# Epoch 8/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8227
# Epoch 9/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5664
# Epoch 10/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7659
# Epoch 11/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8785
# Epoch 12/1000
# ...

# %%
pred1
# Out:
# array([[5.9618487],
#        [4.424556 ],
#        [6.0104117],
#        [4.7816324],
#        [5.6428595],
#        [5.7717876],
#        [5.768115 ],
#        [6.282647 ],
#        [5.774218 ],
#        [5.676605 ],
#        [5.8152146],
#        [6.005149 ],
#        [5.9600916],
#        [5.8186655],
#        [6.180754 ],
#        [5.94955  ],
#        [5.877757 ],
#        [6.2156773],
#        [6.086599 ],
#        [6.0573673],
#        [5.6946983],
#        [5.414199 ],
#        [5.8009634],
#        [5.77431  ],
#        [5.724067 ],
#        [5.747153 ],
#        [5.9302883],
#        [6.07189  ],
#        [5.806281 ],
#        [4.638432 ],
#        [5.6501856],
#        [5.990299 ],
#        [4.496621 ],
#        [4.474002 ],
#        [4.501847 ],
#        [4.4625254],
#        [4.4950304],
#        [4.475603 ],
#        [4.542404 ],
#        [4.56248  ],
#        [4.4626036],
#        [4.525612 ],
#        [4.4341755],
#        [4.5035696],
#        [4.522146 ],
# ...
