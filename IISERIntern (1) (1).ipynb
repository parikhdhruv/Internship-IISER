# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('C:\\Users\HP\Downloads\database.csv')

# %%
train.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01-02-1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01-04-1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01-05-1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01-08-1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01-09-1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
train.isna().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
train.drop(['ID','Magnitude Error','Horizontal Error','Horizontal Distance','Depth Error','Depth Seismic Stations','Magnitude Seismic Stations','Azimuthal Gap'],axis=1,inplace=True)

# %%
train.drop(['Source','Location Source','Magnitude Source'],axis=1,inplace=True)

# %%
pd.get_dummies(train[['Magnitude Type','Status']])
# Out:
#        Magnitude Type_MB  Magnitude Type_MD  Magnitude Type_MH  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 23407                  0                  0                  0
# 23408                  0                  0                  0
# 23409                  0                  0                  0
# 23410                  0                  0                  0
# 23411                  1                  0                  0
#
#        Magnitude Type_ML  Magnitude Type_MS  Magnitude Type_MW  \
# 0                      0                  0                  1
# 1                      0                  0                  1
# ...

# %%
train = pd.get_dummies(train, columns = ['Type','Status','Magnitude Type'])

# %%
train['Root Mean Square'].fillna(train['Root Mean Square'].mean(), inplace=True)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="http")
location = geolocator.reverse("51.5074, 0.1278")

print(location.address)
# Out:
# Fleming Way, London Borough of Bexley, London, Greater London, England, SE28 8NS, United Kingdom

# %%
train['Date'] = pd.to_datetime(train['Date'], errors='coerce',utc=True)

# %%
train['year'] = pd.DatetimeIndex(train['Date']).year

# %%
train['month']=pd.DatetimeIndex(train['Date']).month

# %%
train['month']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 23407    12
# 23408    12
# 23409    12
# 23410    12
# 23411    12
# Name: month, Length: 23412, dtype: int64

# %%
train['Month'] = pd.to_datetime(train['month'], format='%m').dt.strftime('%b')

# %% [raw]
# train['Month']

# %%
train['Month'].value_counts()
# Out:
# Mar    2114
# Aug    2014
# Dec    2001
# Nov    1987
# Sep    1985
# Apr    1971
# May    1964
# Oct    1952
# Jan    1891
# Jul    1880
# Feb    1829
# Jun    1824
# Name: Month, dtype: int64

# %%
locator = Nominatim(user_agent="myGeocoder")
coordinates = "53.480837, -2.244914"
location = locator.reverse(coordinates)

# %%
print(location.address)
# Out:
# 68, Cross Street, Civic Quarter, City Centre, Manchester, Greater Manchester, England, M2 4JN, United Kingdom

# %%
train["geom"] =  train["Longitude"].map(str)  + ',' + train['Latitude'].map(str)
train.head()
# Out:
#                        Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
#
#    Root Mean Square  Type_Earthquake  Type_Explosion  Type_Nuclear Explosion  \
# 0          1.022784                1               0                       0
# 1          1.022784                1               0                       0
# 2          1.022784                1               0                       0
# 3          1.022784                1               0                       0
# 4          1.022784                1               0                       0
#
# ...

# %%
# !pip install geopandas

# %%
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
# !pip install geopandas
import matplotlib.pyplot as plt
import tqdm
from tqdm import tqdm
from tqdm._tqdm_notebook import tqdm_notebook

# %%
locator = Nominatim(user_agent="myGeocoder", timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)
rgeocode

# %%
location.raw
# Out:
# {'place_id': 115318708,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 37139875,
#  'lat': '53.4809609',
#  'lon': '-2.2450805553523505',
#  'display_name': '68, Cross Street, Civic Quarter, City Centre, Manchester, Greater Manchester, England, M2 4JN, United Kingdom',
#  'address': {'house_number': '68',
#   'road': 'Cross Street',
#   'neighbourhood': 'Civic Quarter',
#   'suburb': 'City Centre',
#   'city': 'Manchester',
#   'ISO3166-2-lvl8': 'GB-MAN',
#   'state_district': 'Greater Manchester',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'M2 4JN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  'boundingbox': ['53.4808484', '53.4810728', '-2.2451942', '-2.2449675']}

# %%
train["geom"] =  train["Latitude"].map(str)  + ',' + train['Longitude'].map(str)
train.head()
# Out:
#                        Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
#
#    Root Mean Square  Type_Earthquake  Type_Explosion  Type_Nuclear Explosion  \
# 0          1.022784                1               0                       0
# 1          1.022784                1               0                       0
# 2          1.022784                1               0                       0
# 3          1.022784                1               0                       0
# 4          1.022784                1               0                       0
#
# ...

# %%
locator = Nominatim(user_agent="myGeocoder", timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)
rgeocode

# %%
tqdm.pandas()
train['address'] = train['geom'].progress_apply(rgeocode)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 23412/23412 [3:15:26<00:00,  2.00it/s]

# %%
train.head()
# Out:
#                        Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
#
#    Root Mean Square  Type_Earthquake  Type_Explosion  Type_Nuclear Explosion  \
# 0          1.022784                1               0                       0
# 1          1.022784                1               0                       0
# 2          1.022784                1               0                       0
# 3          1.022784                1               0                       0
# 4          1.022784                1               0                       0
#
# ...

# %%
train.head(16)
# Out:
#                         Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0  1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1  1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2  1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3  1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4  1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
# 5  1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0        6.7
# 6  1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0        5.9
# 7  1965-01-15 00:00:00+00:00  23:17:42   -13.309    166.212   35.0        6.0
# 8  1965-01-16 00:00:00+00:00  11:32:37   -56.452    -27.043   95.0        6.0
# 9  1965-01-17 00:00:00+00:00  10:43:17   -24.563    178.487  565.0        5.8
# 10 1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9        5.9
# ...

# %%
train.address.isnull().sum()
# Out:
# 12261

# %%
print(train['address'].value_counts())
# Out:
# (Maluku, Indonesia, (-3.118837, 129.4207759))                                                                   437
# (Maluku Utara, Indonesia, (0.6301215, 127.9720219))                                                             409
# (Lau, Eastern, Viti, (-18.970617, -179.05844147787496))                                                         268
# (Sulawesi Utara, Indonesia, (0.6555692, 124.090151))                                                            238
# (Alaska, United States, (64.4459613, -149.680909))                                                              174
#                                                                                                                ...
# (Lajawardshoy, ولسوالی کران و منجان, ولایت بدخشان, افغانستان, (36.17284762158625, 70.78015486390387))             1
# (South Butte Avenue, Fresno County, California, United States, (36.14299876249859, -120.15645671990845))          1
# ...

# %%
print(address[141])
# Out:
# El Valle, Dolores Apulo, Municipio de Ilopango, Departamento de San Salvador, 1106, El Salvador

# %%
train[['Place','Country','']] = df.Name.str.split(expand=True)

# %%
train.add

# %%
train['address']
# Out:
# dtype('O')

# %%
train.to_csv('IIserIntern.csv', index=False)

# %%
print(location.address)
# Out:
# 68, Cross Street, Civic Quarter, City Centre, Manchester, Greater Manchester, England, M2 4JN, United Kingdom

# %%
train['geom'].dtypes
# Out:
# dtype('O')

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent="myGeocoder")

# %%
# !pip install reverse_geocoder

# %%
import reverse_geocoder as rg
coordinates = (33.84663415,-84.36281345415213)
location = rg.search(coordinates)
# Out:
# Loading formatted geocoded file...

# %%
location
# Out:
# [{'lat': '33.8651',
#   'lon': '-84.33659',
#   'name': 'North Atlanta',
#   'admin1': 'Georgia',
#   'admin2': 'DeKalb County',
#   'cc': 'US'}]

# %%
latitude=train['Latitude']

# %%
longitude=train['Longitude']

# %%
geom=train['geom']

# %%
geom.dtypes
# Out:
# dtype('O')

# %%
# !pip install geopandas

# %%
train['geometry'] = gpd.points_from_xy(train.Longitude, train.Latitude, crs="EPSG:4326")

# %%
train.head()
# Out:
#                        Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
#
#    Root Mean Square  Type_Earthquake  Type_Explosion  Type_Nuclear Explosion  \
# 0          1.022784                1               0                       0
# 1          1.022784                1               0                       0
# 2          1.022784                1               0                       0
# 3          1.022784                1               0                       0
# 4          1.022784                1               0                       0
#
# ...

# %%
train['geometry'].dtypes

# %%
import geopandas as gpd
gdf = gpd.GeoDataFrame(train, geometry="geometry")
gdf.head(12)
# Out:
#                         Date      Time  Latitude  Longitude  Depth  Magnitude  \
# 0  1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6        6.0
# 1  1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0        5.8
# 2  1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0        6.2
# 3  1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0        5.8
# 4  1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0        5.8
# 5  1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0        6.7
# 6  1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0        5.9
# 7  1965-01-15 00:00:00+00:00  23:17:42   -13.309    166.212   35.0        6.0
# 8  1965-01-16 00:00:00+00:00  11:32:37   -56.452    -27.043   95.0        6.0
# 9  1965-01-17 00:00:00+00:00  10:43:17   -24.563    178.487  565.0        5.8
# 10 1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9        5.9
# ...

# %%
Latitude = "-6.807"
Longitude = "108.988"
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
location = geolocator.reverse(Latitude+","+Longitude)
print(location)
# Out:
# Sawojajar, Brebes, Jawa Tengah, Indonesia

# %%
# !pip install geocoder

# %%
import geocoder

def geo_rev(x):
    g = geocoder.osm([x.Longitude, x.Latitude], method='reverse').json
    if g:
        return g.get('country')
    
train['country']=train[['Longitude', 'Latitude']].tail().apply(geo_rev, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [78], in <cell line: 8>()
#       5     if g:
#       6         return g.get('country')
# ----> 8 train['country']=train[['Longitude', 'Latitude']].tail().apply(geo_rev, axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# ...

# %%
train['country']
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#              ...
# 23407    United States
# 23408    United States
# 23409               日本
# 23410        Indonesia
# 23411             None
# Name: country, Length: 23412, dtype: object

# %%
train['country'].value_counts()
# Out:
# United States    2
# 日本               1
# Indonesia        1
# Name: country, dtype: int64
